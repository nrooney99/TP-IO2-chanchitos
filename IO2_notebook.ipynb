# %% [markdown]
# <a href="https://colab.research.google.com/github/nrooney99/TP-IO2-chanchitos/blob/main/IO2_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Con lobo tirando una sola pared

# %%
import random
import statistics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
for p in range(3,5):
  # p=4 # cantidad de jugadores
  g=100 # cantidad de juegos
  n=[] # array de rondas por juego
  def rollDice():
      return int(random.random()*6)+1
  for k in range(g):
      state = [[0 for col in range(5)] for row in range(p)]
      win=False
      for r in range(100):
          if win == True:
              n.append(r)
              break
          for i in state:
              dice= rollDice()
              if dice == 6:
                  for j in range(len(i)):
                      if i[j]==1:
                          i[j]=0
                          break
              elif dice in [1,2,3,4]:
                  i[dice-1]=1
              elif i==[1,1,1,1,0]:
                  win=True
                  break

  dp = np.array(n)
  IC = st.t.interval (alpha = 0.95, df = len (dp) -1, loc = np.mean (dp), scale = st.sem (dp))
  hw=1.65 * dp.std() / g**(1/2)
  nd=(dp.std()*1.65/0.1/dp.mean())**2

  fig, axs = plt.subplots(1,1,figsize=(4,4))

  #Histograma
  d = {x:n.count(x) for x in n}
  a, b = d.keys(), d.values()
  axs.bar(a, b, width=1, edgecolor="white", linewidth=0.7)

  #BoxPlot
  # axs[1].boxplot(n)

  print(str(p) + ' Jugadores')
  print('Lobo tira una sola pared')
  plt.show()

  #Textos
  print(str(g) + ' Partidas jugadas')
  print('Media: ' + str(dp.mean()))
  print('Desvío: ' + str(dp.std()))
  print('IC 95% de la media: ' + str(IC))
  print('HW: '+ str(hw))
  print('N deseado: ' + str(nd))
  print('\n')
  print(dp)
  print('\n\n------------------------------------------------------------------------------------------------------------------------------')
# Out:
# 3 Jugadores
# Lobo tira una sola pared
# 100 Partidas jugadas
# Media: 17.56
# Desvío: 9.28474016868539
# IC 95% de la media: (15.708424980456813, 19.411575019543186)
# HW: 1.5319821278330894
# N deseado: 76.11291841574088
#
#
# [15 14 24 33 13 11 13 29 13 12 12 16 25 22 17  6 24 19 10 10 10  8 43  8
#  33  7 32 21 10  8 24 24 12 25 22 24  7 17  6 10 10  7 25 25 12 13 23 19
#  15 10 45  6 14 36 17 22 13 12 11 20  8 19 12 16 20 20  7 13 16 12 34 26
#  34 16 13  6  6 18  9  6 37 48 38 23  9 31 16 12 10 21 16 24 15 13 14 13
#  23 13 12 13]
#
#
# ------------------------------------------------------------------------------------------------------------------------------
# 4 Jugadores
# Lobo tira una sola pared
# 100 Partidas jugadas
# Media: 14.84
# Desvío: 6.09051721941577
# IC 95% de la media: (13.625421095831854, 16.054578904168146)
# HW: 1.004935341203602
# N deseado: 45.85729542796114
#
#
# [16 30  8 16 11 16 20 21  8  9 11 17 23 16  7 13  7 11 11 14 13 10 11 12
# ...

# %% [markdown]
# #Con lobo tirando todas las paredes

# %%
import random
import statistics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
for p in range(3,5):
  # p=4 # cantidad de jugadores
  g=200 # cantidad de juegos
  n=[] # array de rondas por juego
  def rollDice():
      return int(random.random()*6)+1
  for k in range(g):
      state = [[0 for col in range(5)] for row in range(p)]
      win=False
      for r in range(100):
          if win == True:
              n.append(r)
              break
          for i in state:
              dice= rollDice()
              if dice == 6:
                  for j in range(len(i)):
                    i[j]=0
              elif dice in [1,2,3,4]:
                  i[dice-1]=1
              elif i==[1,1,1,1,0]:
                  win=True
                  break

  dp = np.array(n)
  IC = st.t.interval (alpha = 0.95, df = len (dp) -1, loc = np.mean (dp), scale = st.sem (dp))
  hw=1.65 * dp.std() / g**(1/2)
  nd=(dp.std()*1.65/0.1/dp.mean())**2

  fig, axs = plt.subplots(1,1,figsize=(4,4))

  #Histograma
  d = {x:n.count(x) for x in n}
  a, b = d.keys(), d.values()
  axs.bar(a, b, width=1, edgecolor="white", linewidth=0.7)

  #BoxPlot
  # axs[1].boxplot(n)

  print(str(p) + ' Jugadores')
  print('Lobo tira todas las paredes')
  plt.show()

  #Textos
  print(str(g) + ' Partidas jugadas')
  print('Media: ' + str(dp.mean()))
  print('Desvío: ' + str(dp.std()))
  print('IC 95% de la media: ' + str(IC))
  print('HW: '+ str(hw))
  print('N deseado: ' + str(nd))
  print('\n')
  print(dp)
  print('\n\n------------------------------------------------------------------------------------------------------------------------------')
# Out:
# 3 Jugadores
# Lobo tira todas las paredes
# 200 Partidas jugadas
# Media: 24.325
# Desvío: 17.316448105775038
# IC 95% de la media: (21.904363276199422, 26.745636723800576)
# HW: 2.0203553504736482
# N deseado: 137.96846167171378
#
#
# [ 9  8 11 33 28 15 30 13 19  5 14 14  9 44 19 13 32 61 32 13 15 14 25 73
#  26 26 18 18 43 12 50 18 53  9  8  9 12 18 76 17 33 55 24  9  8 18 40 53
#  36 61 10 44  7 11 19  7 60 87 23 36 43 16 28 12 10 33 28 55  7 29  7  8
#   6 29 13 28 13 13 30 36  8 17 27 25  9 15  7 20 32 31 11 27 23 22 10 35
#  18 11  8 29  6 21 32 14 28 12 10 84 39 11 25 13 17 11 64 11 28 41 28 17
#  23 13 10  8 13  8 32 11 11 26 13  7 21 57 36 11 24 20  9 18 41 29 19 11
#   6  9  8  9 18 18 41  9 18 23 28 16 10 18 62 22 15 34 53 26 37 11 13 32
#  70 48 47 30 13 23 17 31 72 11 55 29 28 32 10 10 91 48  9 12 17 19 15 17
#  12 17  8 54  5 18 18 28]
#
#
# ------------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Lobo tirando una pared con 1 a 10 jugadores

# %%
import random
import statistics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
t=[]
for p in range(1,11):
  # p=4 # cantidad de jugadores
  g=1000 # cantidad de juegos
  n=[] # array de rondas por juego
  def rollDice():
      return int(random.random()*6)+1
  for k in range(g):
      state = [[0 for col in range(5)] for row in range(p)]
      win=False
      for r in range(100):
          if win == True:
              n.append(r)
              break
          for i in state:
              dice= rollDice()
              if dice == 6:
                  for j in range(len(i)):
                      if i[j]==1:
                          i[j]=0
                          break
              elif dice in [1,2,3,4]:
                  i[dice-1]=1
              elif i==[1,1,1,1,0]:
                  win=True
                  break
  t.append(n)
dp = np.array(t)
df = pd. DataFrame(dp)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#                                                    0
# 0  [55, 11, 24, 58, 48, 9, 18, 48, 15, 31, 29, 29...
# 1  [46, 25, 6, 22, 9, 9, 10, 26, 10, 42, 13, 41, ...
# 2  [19, 15, 38, 12, 18, 36, 13, 12, 29, 26, 9, 22...
# 3  [15, 8, 8, 31, 26, 7, 8, 20, 11, 17, 10, 15, 3...
# 4  [14, 8, 9, 17, 21, 22, 8, 10, 12, 10, 19, 9, 1...
# 5  [10, 19, 9, 9, 10, 7, 14, 12, 6, 16, 18, 15, 1...
# 6  [13, 7, 6, 12, 7, 14, 11, 8, 9, 13, 8, 15, 8, ...
# 7  [9, 9, 10, 13, 12, 8, 9, 10, 19, 9, 10, 8, 16,...
# 8  [14, 12, 6, 9, 12, 7, 7, 6, 8, 6, 8, 10, 9, 8,...
# 9  [8, 20, 10, 15, 9, 13, 8, 10, 10, 11, 12, 10, ...

# %% [markdown]
# # Lobo tirando todas las paredes con 1 a 10 jugadores

# %%
import random
import statistics
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
t=[]
for p in range(1,11):
  # p=4 # cantidad de jugadores
  g=1000 # cantidad de juegos
  n=[] # array de rondas por juego
  def rollDice():
      return int(random.random()*6)+1
  for k in range(g):
      state = [[0 for col in range(5)] for row in range(p)]
      win=False
      for r in range(100):
          if win == True:
              n.append(r)
              break
          for i in state:
              dice= rollDice()
              if dice == 6:
                  for j in range(len(i)):
                    i[j]=0
              elif dice in [1,2,3,4]:
                  i[dice-1]=1
              elif i==[1,1,1,1,0]:
                  win=True
                  break
  t.append(n)
dp = np.array(t)
df = pd. DataFrame(dp)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:32: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#                                                    0
# 0  [81, 79, 92, 49, 51, 20, 62, 56, 9, 25, 9, 29,...
# 1  [13, 10, 31, 71, 10, 29, 31, 45, 18, 21, 44, 9...
# 2  [12, 21, 8, 29, 18, 15, 13, 9, 96, 29, 15, 22,...
# 3  [12, 14, 14, 11, 28, 8, 12, 9, 7, 15, 8, 6, 17...
# 4  [29, 7, 10, 14, 8, 21, 27, 43, 5, 16, 19, 8, 1...
# 5  [25, 12, 10, 12, 10, 8, 22, 11, 8, 15, 16, 6, ...
# 6  [14, 18, 10, 10, 15, 12, 16, 11, 19, 7, 8, 13,...
# 7  [6, 17, 17, 19, 14, 7, 5, 22, 13, 11, 10, 9, 1...
# 8  [10, 9, 23, 5, 6, 7, 6, 9, 22, 18, 8, 10, 9, 1...
# 9  [17, 17, 8, 10, 5, 13, 5, 6, 9, 11, 8, 8, 7, 8...
